# %%
import os
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib import pyplot as plt
from pandas.plotting import scatter_matrix
from sklearn import model_selection
import tensorflow as tf
from __future__ import print_function
from tensorflow.python.ops import resources
from tensorflow.contrib.tensor_forest.python import tensor_forest

folder=r'D:\Ameyem Office\Geoservices\Neeraj & me\log data\\'
df=pd.read_csv('lasdata.csv')

# %%
# las.data.transpose()
Xd=df[df.columns[[0,1,2,3,4,7,9]]]
Yd=df[df.columns[[0,5,6,8,10]]]

X1 = Xd.values[:,0:4] 
Y1 = Yd.values[:,1:2] 
validation_size = 0.20
seed = 7
Xo_train, Xo_test, Y_train, Y_test = model_selection.train_test_split(X1, Y1, test_size=validation_size, random_state=seed)
X_train, X_test =Xo_train[:,1:], Xo_test[:,1:]
scoring = 'accuracy'

n_samples,num_features=X_train.shape
num_classes=Y_train.shape[1]
batch_size=n_samples
# Parameters
batch_size,num_features,num_classes
# Out:
# (1124, 3, 1)

# %%
X_train,Y_train
# Out:
# (array([[126.1824,  59.2583,   8.3752],
#         [119.6835,  58.3405,   5.0548],
#         [126.3542,  65.4497,   5.1967],
#         ...,
#         [107.9646,  55.1028,   8.0347],
#         [101.4942,  53.6725,   5.374 ],
#         [116.2145,  64.7008,   5.9566]]), array([[1.00000e-04],
#         [9.78090e-02],
#         [1.16712e-01],
#         ...,
#         [5.64620e-02],
#         [1.00000e-04],
#         [6.89330e-02]]))

# %%
from sklearn.preprocessing import StandardScaler
scaler_x = StandardScaler()
# Fit only to the training data
scaler_x.fit(X_train)
# Now apply the transformations to the data:
X_train = scaler_x.transform(X_train)
X_test= scaler_x.transform(X_validation)

scaler_y = StandardScaler()
# Fit only to the training data
scaler_y.fit(Y_train)
# Now apply the transformations to the data:
Y_train = scaler_y.transform(Y_train)
Y_test = scaler_y.transform(Y_test)
X_train,Y_train
# Out:
# (array([[ 1.17504613, -0.33069632,  0.47008064],
#         [ 0.45171051, -0.46290355, -0.59352036],
#         [ 1.19416769,  0.56116234, -0.5480665 ],
#         ...,
#         [-0.85261758, -0.92928769,  0.36101061],
#         [-1.57278111, -1.13531952, -0.49127321],
#         [ 0.06560652,  0.45328481, -0.30465294]]), array([[-1.20313147],
#         [ 0.07101759],
#         [ 0.31751729],
#         ...,
#         [-0.46815732],
#         [-1.20313147],
#         [-0.30553245]]))

# %%
def neural_net_model(X_data,input_dim):
    W_1 = tf.Variable(tf.random_uniform([input_dim,10]))
    b_1 = tf.Variable(tf.zeros([10]))
    layer_1 = tf.add(tf.matmul(X_data,W_1), b_1)
    layer_1 = tf.nn.tanh(layer_1)

    W_2 = tf.Variable(tf.random_uniform([10,10]))
    b_2 = tf.Variable(tf.zeros([10]))
    layer_2 = tf.add(tf.matmul(layer_1,W_2), b_2)
    layer_2 = tf.nn.tanh(layer_2)

    W_O = tf.Variable(tf.random_uniform([10,1]))
    b_O = tf.Variable(tf.zeros([1]))
    output = tf.add(tf.matmul(layer_2,W_O), b_O)

    return output,W_O

# %%
import seaborn as sns
xs = tf.placeholder("float")
ys = tf.placeholder("float")

output,W_O = neural_net_model(xs,3)

cost = tf.reduce_mean(tf.square(output-ys))
train = tf.train.AdamOptimizer(0.01).minimize(cost)

correct_pred = tf.argmax(output, 1)
accuracy = tf.reduce_mean(tf.cast(correct_pred,tf.float32))

c_t = []
c_test = []


with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

    saver = tf.train.Saver()
    y_t = Y_train
    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)
    plt.xlabel('Days')
    plt.ylabel('Stock Value INR')
    plt.title('Nify Stock Index Prediction')
    ax.plot(range(len(Y_train)), y_t,label='Original')
    plt.ion()

    #saver.restore(sess,'yahoo_dataset.ckpt')
    for i in range(1000):
        sess.run([cost,train],feed_dict={xs:X_train, ys:Y_train})
#         for j in range(X_train.shape[0]):
#             sess.run([cost,train],feed_dict={xs:X_train[j,:].reshape(1,3), ys:Y_train[j]})

#         try:
#             ax.lines.remove(lines[0])
#         except Exception:
#             pass
        pred = sess.run(output, feed_dict={xs:X_train})
#         pred = denormalize(df_train,pred)
#         lines = ax.plot(range(len(y_train)), pred,'r-',label='Prediction')
#         plt.legend(loc='best')
#         plt.pause(0.1)

        c_t.append(sess.run(cost, feed_dict={xs:X_train,ys:Y_train}))
        c_test.append(sess.run(cost, feed_dict={xs:X_test,ys:Y_test}))
        if i%100==0:
            print('Epoch :',i,'Cost :',c_t[i])

    pred = sess.run(output, feed_dict={xs:X_test})
    
    for i in range(Y_test.shape[0]):
        print('Original :',Y_test[i],'Predicted :',pred[i])

    #plt.plot(range(50),c_t)
    #plt.plot(range(50),c_test)
    #plt.show()

    print('Cost :',sess.run(cost, feed_dict={xs:X_test,ys:Y_test}))
#     y_test = denormalize(df_test,y_test)
#     pred = denormalize(df_test,pred)
    plt.plot(range(Y_test.shape[0]),Y_test,label="Original Data")
    plt.plot(range(Y_test.shape[0]),pred,label="Predicted Data")
    plt.legend(loc='best')
    """plt.ylabel('Stock Value')
    plt.xlabel('Days')
    plt.title('Stock Market Nifty')"""
    #plt.show()
    if input('Save model ? [Y/N]') == 'Y':
        import os
        saver.save(sess, os.getcwd() + '/log_nn.ckpt')
        print('Model Saved')
# Out:
# Epoch : 0 Cost : 33.591812
# Epoch : 100 Cost : 18.353668
# Epoch : 200 Cost : 7.855105
# Epoch : 300 Cost : 3.1288145
# Epoch : 400 Cost : 1.4177648
# Epoch : 500 Cost : 0.7821251
# Epoch : 600 Cost : 0.5826953
# Epoch : 700 Cost : 0.5241623
# Epoch : 800 Cost : 0.49916738
# Epoch : 900 Cost : 0.48237425
# Original : [0.85830919] Predicted : [-1.2625905]
# Original : [1.21445126] Predicted : [-1.2688881]
# Original : [-1.20313147] Predicted : [-1.3365449]
# Original : [1.10068818] Predicted : [-1.325121]
# Original : [1.33011821] Predicted : [-1.3234702]
# Original : [0.316774] Predicted : [-1.3324375]
# Original : [-0.03428237] Predicted : [-1.3296341]
# Original : [-0.86206392] Predicted : [-1.3309869]
# Original : [0.65327746] Predicted : [-1.3090159]
# Original : [0.11158578] Predicted : [-1.3321689]
# Original : [-0.97437953] Predicted : [-1.3285512]
# Original : [0.53270738] Predicted : [-1.3178529]
# Original : [-1.20443549] Predicted : [-1.2837709]
# Original : [1.45336154] Predicted : [-1.3238229]
# Original : [-1.20313147] Predicted : [-1.3210686]
# Original : [0.27529299] Predicted : [-1.3238446]
# Original : [0.16171248] Predicted : [-1.3290318]
# Original : [0.55427594] Predicted : [-1.3264574]
# Original : [0.07605112] Predicted : [-1.3276247]
# Original : [-0.41898256] Predicted : [-1.332005]
# Original : [-0.85876474] Predicted : [-1.3291556]
# Original : [0.78819181] Predicted : [-1.324973]
# Original : [-0.08980772] Predicted : [-1.3250936]
# Original : [0.67097307] Predicted : [-1.3324122]
# Original : [-0.77095175] Predicted : [-1.3316731]
# Original : [-1.20313147] Predicted : [-1.3223993]
# Original : [-0.33036108] Predicted : [-1.3304976]
# Original : [-0.42117332] Predicted : [-1.3332635]
# Original : [-0.82343873] Predicted : [-1.3296992]
# Original : [-0.98096486] Predicted : [-1.3292059]
# Original : [-0.19684203] Predicted : [-1.3275582]
# Original : [-1.20313147] Predicted : [-1.3143791]
# Original : [-0.37182905] Predicted : [-1.3317897]
# Original : [-1.20313147] Predicted : [-1.3363343]
# Original : [-1.20313147] Predicted : [-1.3328912]
# Original : [-1.20313147] Predicted : [-1.330243]
# Original : [-0.47347774] Predicted : [-1.3282303]
# Original : [-1.05490303] Predicted : [-1.3321741]
# Original : [-1.20313147] Predicted : [-1.3299023]
# Original : [-0.99532216] Predicted : [-1.3345761]
# Original : [2.70208212] Predicted : [-0.3704965]
# Original : [-0.41038904] Predicted : [-1.3303672]
# Original : [0.17241852] Predicted : [-1.3286473]
# Original : [2.04854429] Predicted : [-1.2250295]
# Original : [-0.83183664] Predicted : [-1.3278755]
# Original : [-1.20313147] Predicted : [-1.3268415]
# Original : [1.73033629] Predicted : [-1.3216008]
# Original : [0.26426094] Predicted : [-1.3306564]
# Original : [-1.20443549] Predicted : [-1.22099]
# Original : [0.42349535] Predicted : [-1.3163003]
# Original : [-1.20313147] Predicted : [-1.3179904]
# Original : [-0.96127409] Predicted : [-1.336844]
# Original : [-0.23107267] Predicted : [-1.3320607]
# Original : [-0.0177995] Predicted : [-1.3231543]
# Original : [-1.20313147] Predicted : [-1.3365546]
# Original : [-1.20313147] Predicted : [-1.332752]
# Original : [1.68176139] Predicted : [-1.3225759]
# Original : [-0.49402916] Predicted : [-1.333542]
# Original : [-1.20313147] Predicted : [-1.3359703]
# Original : [0.25488501] Predicted : [-1.3326199]
# Original : [-1.20313147] Predicted : [-1.3268842]
# Original : [1.35938051] Predicted : [-1.3227447]
# Original : [-0.58965326] Predicted : [-1.3316386]
# Original : [0.54499129] Predicted : [-1.3074068]
# Original : [-0.59820766] Predicted : [-1.3251156]
# Original : [0.67037322] Predicted : [-1.3306602]
# Original : [-1.20313147] Predicted : [-1.2770315]
# Original : [0.18583693] Predicted : [-1.3313186]
# Original : [0.18698447] Predicted : [-1.3222791]
# Original : [-0.64645655] Predicted : [-1.3298296]
# Original : [-1.20313147] Predicted : [-1.305566]
# Original : [-0.17888562] Predicted : [-1.325539]
# Original : [0.83355881] Predicted : [-1.3214008]
# Original : [-0.02928796] Predicted : [-1.3312514]
# Original : [0.5586705] Predicted : [-1.3319185]
# Original : [-0.62118456] Predicted : [-1.3309833]
# Original : [0.31636975] Predicted : [-1.3326473]
# Original : [1.05431708] Predicted : [-1.3120016]
# Original : [-1.20313147] Predicted : [-1.3330576]
# Original : [-0.5189621] Predicted : [-1.3229829]
# Original : [-0.62836974] Predicted : [-1.3307415]
# Original : [-0.76087164] Predicted : [-1.3316027]
# Original : [-1.20313147] Predicted : [-1.3317959]
# Original : [0.800567] Predicted : [-1.3227893]
# Original : [-1.20443549] Predicted : [-1.3245224]
# Original : [0.8911054] Predicted : [-1.3311884]
# Original : [-0.91824129] Predicted : [-1.3288373]
# Original : [0.17514393] Predicted : [-1.3316019]
# Original : [-1.20313147] Predicted : [-1.3305188]
# Original : [-1.20313147] Predicted : [-1.3296174]
# Original : [1.02054285] Predicted : [-1.3262872]
# Original : [2.03612998] Predicted : [-1.3214437]
# Original : [-1.20313147] Predicted : [-1.3316504]
# Original : [0.53069918] Predicted : [-1.3299779]
# Original : [-1.20313147] Predicted : [-1.3350511]
# Original : [-1.20313147] Predicted : [-1.318602]
# Original : [0.17395726] Predicted : [-1.3312552]
# Original : [0.05874672] Predicted : [-1.32696]
# Original : [2.24006633] Predicted : [-0.43723297]
# Original : [1.43590066] Predicted : [-1.2497864]
# Original : [-1.20313147] Predicted : [-1.320922]
# Original : [1.83665339] Predicted : [-1.1568178]
# Original : [-1.20313147] Predicted : [-1.3323454]
# Original : [-1.20313147] Predicted : [-1.3305258]
# Original : [0.49802033] Predicted : [-1.3194672]
# Original : [-0.53028103] Predicted : [-1.3266851]
# Original : [-1.20313147] Predicted : [-1.3264812]
# Original : [1.27803548] Predicted : [-1.2123287]
# Original : [-0.21273809] Predicted : [-1.3320211]
# Original : [0.96119671] Predicted : [-1.3310869]
# Original : [-1.20443549] Predicted : [-1.2603686]
# Original : [0.42658588] Predicted : [-1.327227]
# Original : [0.62637544] Predicted : [-1.3317968]
# Original : [-1.20313147] Predicted : [-1.3249122]
# Original : [-0.40692034] Predicted : [-1.3239955]
# Original : [-0.74712723] Predicted : [-1.3327907]
# Original : [-1.20313147] Predicted : [-1.3365299]
# Original : [-1.06108411] Predicted : [-1.3281223]
# Original : [-0.63808472] Predicted : [-1.323439]
# Original : [-1.20313147] Predicted : [-1.3296295]
# Original : [1.78940859] Predicted : [-1.3176264]
# Original : [0.72190826] Predicted : [-1.3319558]
# Original : [-0.75832879] Predicted : [-1.3317583]
# Original : [-1.20443549] Predicted : [-1.2919923]
# Original : [-1.03805504] Predicted : [-1.3293806]
# Original : [-0.91752408] Predicted : [-1.329651]
# Original : [0.81642393] Predicted : [-1.3295771]
# Original : [-0.17415201] Predicted : [-1.327459]
# Original : [0.92620974] Predicted : [-1.3210701]
# Original : [1.20562301] Predicted : [-1.3085328]
# Original : [-1.20443549] Predicted : [-1.3198792]
# Original : [0.47839477] Predicted : [-1.3297435]
# Original : [1.68418687] Predicted : [-1.3210839]
# Original : [-0.51687566] Predicted : [-1.3329777]
# Original : [-1.20313147] Predicted : [-1.2459898]
# Original : [-1.20313147] Predicted : [-1.3272551]
# Original : [1.16712822] Predicted : [-1.3197044]
# Original : [0.06484956] Predicted : [-1.3259453]
# Original : [0.88642396] Predicted : [-1.32891]
# Original : [0.43876547] Predicted : [-1.2913283]
# Original : [-0.55422292] Predicted : [-1.3276476]
# Original : [-0.77415965] Predicted : [-1.3292607]
# Original : [-1.20313147] Predicted : [-1.3224233]
# Original : [1.4974506] Predicted : [-1.3217267]
# Original : [1.54679488] Predicted : [-1.3231062]
# Original : [1.72033443] Predicted : [-1.3234347]
# Original : [-0.56829334] Predicted : [-1.3276418]
# Original : [-1.20313147] Predicted : [-1.3101555]
# Original : [-0.33063492] Predicted : [-1.3295664]
# Original : [-0.00752379] Predicted : [-1.3282033]
# Original : [0.02331638] Predicted : [-1.3321894]
# Original : [1.53719726] Predicted : [-1.2822503]
# Original : [1.12541248] Predicted : [-1.3222011]
# Original : [-0.48860442] Predicted : [-1.3317399]
# Original : [0.74012547] Predicted : [-1.32081]
# Original : [-1.20313147] Predicted : [-1.3147141]
# Original : [-0.89483405] Predicted : [-1.3296672]
# Original : [0.22799603] Predicted : [-1.3257359]
# Original : [1.61602553] Predicted : [-1.3220283]
# Original : [1.57981277] Predicted : [-1.3218893]
# Original : [1.52506983] Predicted : [-1.2310044]
# Original : [-0.09610616] Predicted : [-1.3190569]
# Original : [-0.00114711] Predicted : [-1.332779]
# Original : [-1.02047679] Predicted : [-1.3241848]
# Original : [0.99377123] Predicted : [-1.3318021]
# Original : [-0.95483221] Predicted : [-1.330325]
# Original : [-0.59798597] Predicted : [-1.3313266]
# Original : [-1.02720556] Predicted : [-1.3251504]
# Original : [1.09798885] Predicted : [-1.2941335]
# Original : [0.62216344] Predicted : [-1.3329346]
# Original : [1.05463004] Predicted : [-1.3223218]
# Original : [1.5039316] Predicted : [-1.3069342]
# Original : [-1.20443549] Predicted : [-1.2161998]
# Original : [-1.20313147] Predicted : [-1.3243397]
# Original : [-1.0361642] Predicted : [-1.3282882]
# Original : [-1.04158894] Predicted : [-1.3298646]
# Original : [-0.92633928] Predicted : [-1.3365651]
# Original : [0.36524458] Predicted : [-1.322848]
# Original : [0.95415498] Predicted : [-1.3060654]
# Original : [1.55544056] Predicted : [-1.3256472]
# Original : [1.52909927] Predicted : [-1.3294321]
# Original : [-0.51104668] Predicted : [-1.327237]
# Original : [0.01829589] Predicted : [-1.3288127]
# Original : [-1.20313147] Predicted : [-1.3255016]
# Original : [0.74115565] Predicted : [-1.320248]
# Original : [-0.28213826] Predicted : [-1.3302027]
# Original : [-0.08825593] Predicted : [-1.3218762]
# Original : [-0.05565533] Predicted : [-1.3261195]
# Original : [1.97305433] Predicted : [-1.2342529]
# Original : [0.35083511] Predicted : [-1.330871]
# Original : [-0.7565162] Predicted : [-1.3286737]
# Original : [1.28213012] Predicted : [-1.2120773]
# Original : [-1.20313147] Predicted : [-1.3263882]
# Original : [-0.67042452] Predicted : [-1.3313544]
# Original : [1.63548157] Predicted : [-1.3226253]
# Original : [-1.20313147] Predicted : [-1.328539]
# Original : [0.15305376] Predicted : [-1.2628926]
# Original : [-1.20313147] Predicted : [-1.3208495]
# Original : [-1.20313147] Predicted : [-1.3295616]
# Original : [-0.0465402] Predicted : [-1.3324857]
# Original : [1.4511447] Predicted : [-1.3229688]
# Original : [-0.95313698] Predicted : [-1.3361547]
# Original : [0.48402815] Predicted : [-1.3122984]
# Original : [1.80225323] Predicted : [-1.3201014]
# Original : [0.09771097] Predicted : [-1.3298522]
# Original : [0.34241112] Predicted : [-1.3253995]
# Original : [-0.64208807] Predicted : [-1.3261911]
# Original : [-0.85336608] Predicted : [-1.328725]
# Original : [0.05372623] Predicted : [-1.3291644]
# Original : [0.80562661] Predicted : [-1.3278414]
# Original : [-1.20313147] Predicted : [-1.2988707]
# Original : [-1.20313147] Predicted : [-1.3240823]
# Original : [1.34567522] Predicted : [-1.1916156]
# Original : [-1.20313147] Predicted : [-1.3315674]
# Original : [-0.20255366] Predicted : [-1.3234774]
# Original : [-1.0244671] Predicted : [-1.3288697]
# Original : [0.69359789] Predicted : [-1.3294135]
# Original : [-1.20313147] Predicted : [-1.3198229]
# Original : [-1.20313147] Predicted : [-1.3219653]
# Original : [-0.20161476] Predicted : [-1.3272372]
# Original : [-0.81412799] Predicted : [-1.3321149]
# Original : [1.49824605] Predicted : [-1.1963857]
# Original : [-1.20313147] Predicted : [-1.3210593]
# Original : [-1.03268246] Predicted : [-1.3370583]
# Original : [1.88735385] Predicted : [-1.2539093]
# Original : [0.32483287] Predicted : [-1.3245491]
# Original : [1.9233058] Predicted : [-1.3154329]
# Original : [0.57708332] Predicted : [-1.32258]
# Original : [1.68679492] Predicted : [-1.3052799]
# Original : [-1.20313147] Predicted : [-1.3368642]
# Original : [0.30295134] Predicted : [-1.3321041]
# Original : [-1.20313147] Predicted : [-1.2876648]
# Original : [-0.77714586] Predicted : [-1.3301193]
# Original : [0.82680397] Predicted : [-1.3167275]
# Original : [0.49725096] Predicted : [-1.328138]
# Original : [0.8727969] Predicted : [-1.3291873]
# Original : [-0.20774367] Predicted : [-1.3146452]
# Original : [-0.26634652] Predicted : [-1.3337243]
# Original : [1.0659881] Predicted : [-1.301154]
# Original : [-1.20313147] Predicted : [-1.3265365]
# Original : [-1.20313147] Predicted : [-1.3073298]
# Original : [-0.18627944] Predicted : [-1.3238503]
# Original : [1.94260536] Predicted : [-1.3236834]
# Original : [-1.20313147] Predicted : [-1.3261181]
# Original : [0.25094686] Predicted : [-1.3279954]
# Original : [1.77010903] Predicted : [-1.3246444]
# Original : [-0.76550093] Predicted : [-1.3355734]
# Original : [-0.33836778] Predicted : [-1.3310875]
# Original : [-1.20313147] Predicted : [-1.3363705]
# Original : [-1.20313147] Predicted : [-1.3303076]
# Original : [-0.32604475] Predicted : [-1.327469]
# Original : [-0.33204327] Predicted : [-1.3309075]
# Original : [-1.20443549] Predicted : [-1.3102468]
# Original : [-1.20443549] Predicted : [-1.3156914]
# Original : [0.4997938] Predicted : [-1.3055605]
# Original : [-0.32610996] Predicted : [-1.3070241]
# Original : [0.27383248] Predicted : [-1.2698923]
# Original : [-0.06243625] Predicted : [-1.3289181]
# Original : [-0.75416896] Predicted : [-1.3318975]
# Original : [-0.6037628] Predicted : [-1.3313715]
# Original : [-1.20313147] Predicted : [-1.3017231]
# Original : [-1.20443549] Predicted : [-1.3206354]
# Original : [-1.20313147] Predicted : [-1.3282]
# Original : [0.17978625] Predicted : [-1.3217684]
# Original : [-1.20313147] Predicted : [-1.3309263]
# Original : [1.60700168] Predicted : [-1.2413394]
# Original : [0.28779858] Predicted : [-1.3316342]
# Original : [0.86815458] Predicted : [-1.2991902]
# Original : [0.55687095] Predicted : [-1.3327311]
# Original : [-0.54457314] Predicted : [-1.32069]
# Original : [0.6018989] Predicted : [-1.3260134]
# Original : [-0.98572454] Predicted : [-1.3371587]
# Original : [0.11579778] Predicted : [-1.3274757]
# Original : [-1.20313147] Predicted : [-1.3256441]
# Original : [0.65142574] Predicted : [-1.3317754]
# Original : [1.29228846] Predicted : [-1.3311522]
# Original : [0.95052979] Predicted : [-1.2955898]
# Original : [0.8048442] Predicted : [-1.3151659]
# Original : [0.97414567] Predicted : [-1.3248664]
# Original : [-0.00344219] Predicted : [-1.3335373]
# Original : [-1.20313147] Predicted : [-1.3293499]
# Cost : 2.484226
# Save model ? [Y/N]y

# %%
# Y_train,Y_pred
xid=0
yid=0
#     #Graphic display
# plt.plot(Xo_train[:,xid], Y_train[:,yid], 'r.', label='Original data')
# plt.plot(Xo_train[:,xid], Y_pred[:,yid],'b.', label='Fitted line')
plt.plot(Y_train[:,yid], Y_pred[:,yid],'b*', label='Fitted line')
plt.legend()
plt.show()

# %%
X_train.shape,X_train[j,:].reshape(1,3).shape
# X_train
# Out:
# ((1124, 3), (1, 3))
