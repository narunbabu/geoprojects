# %%
import pandas as pd
import numpy as np
import pickle
raw_logs_pickle='kharsang_edited_logs.pkl'
calc_logs_pickle='kharsang_calculated_logs.pkl'
# calc_folder=r'D:\Arun\Blade_project\Blade Petrophysics\BLADE-KHARSANG CALCULATED LOG ANALYSIS\\'
# folder=r'D:\Arun\Blade_project\Blade Petrophysics\BLADE-KHARSANG EDITLOG LAS\\'
cols=[]

lases = pickle.load(open(raw_logs_pickle, 'rb')) # saved with lasio

# %%
for las in lases:
#     las.append(lasio.read(calc_folder+file))
    cols.append([a.lower() for a in las.keys()])
#     df=pd.DataFrame(las.data,columns=las.keys())
#     df.to_csv('lasdata.csv',index=False)
cols
# Out:
# [['depth', 'b_dres', 'b_dt', 'b_gr', 'b_spbl', 'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth', 'b_cali', 'b_dres', 'b_gr', 'b_npls', 'b_rhob', 'b_spbl', 'b_sres'],
#  ['depth', 'b_cali', 'b_dres', 'b_gr', 'b_npls', 'b_rhob', 'b_spbl', 'b_sres'],
#  ['depth', 'b_cali', 'b_dres', 'b_gr', 'b_npls', 'b_rhob', 'b_spbl', 'b_sres'],
#  ['depth', 'b_cali', 'b_dres', 'b_gr', 'b_npls', 'b_rhob', 'b_spbl', 'b_sres'],
#  ['depth', 'b_cali', 'b_dres', 'b_gr', 'b_npls', 'b_rhob', 'b_spbl', 'b_sres'],
#  ['depth', 'b_cali', 'b_dres', 'b_gr', 'b_npls', 'b_rhob', 'b_spbl', 'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_dt',
#   'b_gr',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth', 'b_cali', 'b_dres', 'b_gr', 'b_npls', 'b_rhob', 'b_spbl', 'b_sres'],
#  ['depth', 'b_cali', 'b_dres', 'b_gr', 'b_npls', 'b_rhob', 'b_spbl', 'b_sres'],
#  ['depth', 'b_cali', 'b_dres', 'b_gr', 'b_npls', 'b_rhob', 'b_spbl', 'b_sres'],
#  ['depth', 'b_cali', 'b_dres', 'b_gr', 'b_npls', 'b_rhob', 'b_spbl', 'b_sres'],
#  ['depth', 'b_cali', 'b_dres', 'b_gr', 'b_npls', 'b_rhob', 'b_spbl', 'b_sres'],
#  ['depth', 'b_cali', 'b_dres', 'b_gr', 'b_npls', 'b_rhob', 'b_spbl', 'b_sres'],
#  ['depth', 'b_cali', 'b_dres', 'b_gr', 'b_npls', 'b_rhob', 'b_spbl', 'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_dt',
#   'b_gr',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth', 'b_cali', 'b_dres', 'b_gr', 'b_npls', 'b_rhob', 'b_spbl', 'b_sres'],
#  ['depth', 'b_cali', 'b_dres', 'b_gr', 'b_npls', 'b_rhob', 'b_spbl', 'b_sres'],
#  ['depth', 'b_cali', 'b_dres', 'b_gr', 'b_npls', 'b_rhob', 'b_spbl', 'b_sres'],
#  ['depth', 'b_cali', 'b_dres', 'b_gr', 'b_npls', 'b_rhob', 'b_spbl', 'b_sres'],
#  ['depth', 'b_cali', 'b_dres', 'b_gr', 'b_npls', 'b_rhob', 'b_spbl', 'b_sres'],
#  ['depth', 'b_cali', 'b_dres', 'b_gr', 'b_npls', 'b_rhob', 'b_spbl', 'b_sres'],
#  ['depth', 'b_cali', 'b_dres', 'b_gr', 'b_npls', 'b_rhob', 'b_spbl', 'b_sres'],
#  ['depth', 'b_cali', 'b_dres', 'b_gr', 'b_npls', 'b_rhob', 'b_spbl', 'b_sres'],
#  ['depth', 'b_cali', 'b_dres', 'b_gr', 'b_npls', 'b_rhob', 'b_spbl', 'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_dt',
#   'b_gr',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth', 'b_cali', 'b_dt', 'b_gr', 'b_npls', 'b_rhob'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_dt',
#   'b_gr',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_dt',
#   'b_gr',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth', 'b_cali', 'b_dres', 'b_gr', 'b_npls', 'b_rhob', 'b_spbl', 'b_sres'],
#  ['depth', 'b_cali', 'b_dres', 'b_gr', 'b_npls', 'b_rhob', 'b_spbl', 'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_dt',
#   'b_gr',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth', 'b_cali', 'b_dres', 'b_gr', 'b_npls', 'b_rhob', 'b_spbl', 'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_ai',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_perm',
#   'b_rhob',
#   'b_spbl',
#   'b_sres',
#   'tvd',
#   'tvdss'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_dt',
#   'b_gr',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres'],
#  ['depth',
#   'b_cali',
#   'b_dres',
#   'b_drho',
#   'b_dt',
#   'b_gr',
#   'b_mres',
#   'b_npls',
#   'b_rhob',
#   'b_spbl',
#   'b_sres']]

# %%
lases[0].data
df=pd.DataFrame(lases[0].data,columns=lases[0].keys())
df
# Out:
#            DEPTH   B_DRES     B_DT     B_GR   B_SPBL   B_SRES
# 0       140.3604      NaN      NaN      NaN      NaN      NaN
# 1       140.5128      NaN      NaN      NaN      NaN      NaN
# 2       140.6652      NaN      NaN      NaN      NaN      NaN
# 3       140.8176      NaN      NaN      NaN      NaN      NaN
# 4       140.9700      NaN      NaN      NaN      NaN      NaN
# 5       141.1224      NaN      NaN      NaN      NaN      NaN
# 6       141.2748      NaN      NaN      NaN      NaN      NaN
# 7       141.4272      NaN      NaN      NaN      NaN      NaN
# 8       141.5796      NaN      NaN      NaN      NaN      NaN
# 9       141.7320      NaN      NaN      NaN      NaN      NaN
# 10      141.8844      NaN      NaN      NaN      NaN      NaN
# 11      142.0368      NaN      NaN      NaN      NaN      NaN
# 12      142.1892      NaN      NaN      NaN      NaN      NaN
# 13      142.3416      NaN      NaN      NaN      NaN      NaN
# 14      142.4940      NaN      NaN      NaN      NaN      NaN
# 15      142.6464      NaN      NaN      NaN      NaN      NaN
# 16      142.7988      NaN      NaN      NaN      NaN      NaN
# 17      142.9512      NaN      NaN      NaN      NaN      NaN
# 18      143.1036      NaN      NaN  56.3155      NaN      NaN
# 19      143.2560      NaN      NaN  54.7639      NaN      NaN
# 20      143.4084      NaN      NaN  52.9762      NaN      NaN
# 21      143.5608      NaN      NaN  51.3733      NaN      NaN
# 22      143.7132      NaN      NaN  50.8745      NaN      NaN
# 23      143.8656      NaN      NaN  51.1165      NaN      NaN
# 24      144.0180      NaN      NaN  52.3006      NaN      NaN
# 25      144.1704      NaN      NaN  55.2123      NaN      NaN
# 26      144.3228      NaN      NaN  56.5337      NaN      NaN
# 27      144.4752      NaN      NaN  56.7673      NaN      NaN
# 28      144.6276      NaN      NaN  55.7120      NaN      NaN
# 29      144.7800      NaN      NaN  54.2340      NaN      NaN
# ...          ...      ...      ...      ...      ...      ...
# 11099  1831.8480  13.4132  91.0739  73.8424 -26.4015  19.4416
# 11100  1832.0004  13.2641  91.7383  70.0073 -26.0401  19.0988
# 11101  1832.1528  13.1147  92.2004  68.5717 -25.8756  18.5036
# 11102  1832.3052  12.8762  92.0702  70.7072 -25.5559  17.9076
# 11103  1832.4576  12.5616  91.4024  74.6494 -25.5462  17.4289
# 11104  1832.6100  12.3238  90.5351  79.1087 -25.5886  17.0858
# 11105  1832.7624  12.0866  90.7021  78.6291 -25.7526  16.8589
# 11106  1832.9148  11.9267  90.8015  78.3970 -25.7375  16.7872
# 11107  1833.0672  11.8320  91.1025  77.3991 -25.5544  16.7930
# 11108  1833.2196  11.5276  91.7414  75.9259 -25.2155  16.6438
# 11109  1833.3720  10.6538  92.5233  74.2301 -24.4027  16.5313
# 11110  1833.5244   9.5229  92.7707  76.4794 -23.4446  15.8561
# 11111  1833.6768   8.4617  92.7839  79.9689 -22.6496  14.9892
# 11112  1833.8292   7.8667  93.2038  81.4741 -21.4431  13.8765
# 11113  1833.9816   7.6292  93.4300  84.2967 -18.7640  12.8635
# 11114  1834.1340   7.5314  93.9113  88.2362 -15.3207  11.6375
# 11115  1834.2864   7.5373  94.9607  91.3151  -9.9761   9.8237
# 11116  1834.4388   7.5430  95.8312  91.7865  -4.9331   8.8275
# 11117  1834.5912   7.5488  96.3722  89.4200  -2.7747   8.5566
# 11118  1834.7436   7.6322  96.9094  84.8899  -2.9244   8.5385
# 11119  1834.8960   7.5605  97.0061  81.0931  -6.1298   8.8008
# 11120  1835.0484   7.5663  96.6837  82.1176 -13.0471   9.0392
# 11121  1835.2008   7.5721  96.6059  86.1621 -16.3796   8.8008
# 11122  1835.3532   7.5004      NaN      NaN -14.9668   8.1044
# 11123  1835.5056   7.5837      NaN      NaN -10.5179   7.9713
# 11124  1835.6580   7.5895      NaN      NaN  -5.0342   8.0906
# 11125  1835.8104      NaN      NaN      NaN      NaN      NaN
# 11126  1835.9628      NaN      NaN      NaN      NaN      NaN
# 11127  1836.1152      NaN      NaN      NaN      NaN      NaN
# 11128  1836.2676      NaN      NaN      NaN      NaN      NaN
#
# [11129 rows x 6 columns]

# %%
# las2[0].keys()
# Out:
# ['DEPTH', 'B_DRES', 'B_DT', 'B_GR', 'B_SPBL', 'B_SRES']
